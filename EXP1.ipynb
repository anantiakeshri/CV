# %%
# Importing Libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load an image from Colab's file system
image_path = 'Kasol.jpg'  # Update this with the actual uploaded image path
print("Image path:", image_path)
image = cv2.imread(image_path)

# Convert the image to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Color Histogram
hist = cv2.calcHist([image], [0, 1, 2], None, [256, 256, 256], [0, 256, 0, 256, 0, 256])
hist = cv2.normalize(hist, hist).flatten()
# Out:
# Image path: Kasol.jpg

# %%
# Edge Detection (Canny)
edges = cv2.Canny(gray_image, 100, 200)

# HOG (Histogram of Oriented Gradients)
hog = cv2.HOGDescriptor()
hog_features = hog.compute(gray_image)

# Display the results using matplotlib
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Original Image')
plt.axis('off')
plt.show()

plt.imshow(edges, cmap='gray')
plt.title('Edges (Canny)')
plt.axis('off')
plt.show()

# %%
# Print feature extraction results
print("Color Histogram:")
print(hist)

print("\nHOG Features:")
print(hog_features.flatten())
# Out:
# Color Histogram:
# [0.02888994 0.00701006 0.         ... 0.         0.0073641  0.4984222 ]
#
# HOG Features:
# [0.10211596 0.0350401  0.03844853 ... 0.10217635 0.130711   0.17759968]
